# %%
import ast
import pandas as pd

# %%
routes_hard =[]

with open ('hard_route.txt', 'r', encoding='utf8') as f:
    routes_hard = f.read()

# %%
routes_list = ast.literal_eval(routes_hard)
pd.DataFrame(routes_list)
# Out:
#                         route_id     vehicle  weight  \
# 0     company_1_DESTINATION_TEST  66LD 94467      20
# 1     company_1_DESTINATION_TEST  51LD 38199      18
# 2     company_1_DESTINATION_TEST  66LD 93106      15
# 3     company_1_DESTINATION_TEST  53LD 10175       9
# 4     company_1_DESTINATION_TEST  68LD 67509       8
# ..                           ...         ...     ...
# 145  company_30_DESTINATION_TEST  66LD 94467      20
# 146  company_30_DESTINATION_TEST  51LD 38199      18
# 147  company_30_DESTINATION_TEST  66LD 93106      15
# 148  company_30_DESTINATION_TEST  53LD 10175       9
# 149  company_30_DESTINATION_TEST  68LD 67509       8
#
#                                                 routes  driver_cost  \
# 0    [[261 KP. 3, QL. 1A, TT. Bến Lức, H. Bến Lức, ...      48000.0
# 1    [[261 KP. 3, QL. 1A, TT. Bến Lức, H. Bến Lức, ...     101280.0
# 2    [[261 KP. 3, QL. 1A, TT. Bến Lức, H. Bến Lức, ...     101280.0
# ...
